# %%
import pandas as pd

# Load the dataset
file_path = "C:\\Users\\Parag\\Desktop\\assesment2\\parag\\Crime_Data_from_2010_to_2019.csv"
crime_data = pd.read_csv(file_path)

# Display the first few rows of the dataset to understand its structure
crime_data.head()
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA
# 0    1307355  02/20/2010 12:00:00 AM  02/20/2010 12:00:00 AM      1350     13  \
# 1   11401303  09/13/2010 12:00:00 AM  09/12/2010 12:00:00 AM        45     14
# 2   70309629  08/09/2010 12:00:00 AM  08/09/2010 12:00:00 AM      1515     13
# 3   90631215  01/05/2010 12:00:00 AM  01/05/2010 12:00:00 AM       150      6
# 4  100100501  01/03/2010 12:00:00 AM  01/02/2010 12:00:00 AM      2100      1
#
#    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd
# 0     Newton         1385         2     900  \
# 1    Pacific         1485         2     740
# 2     Newton         1324         2     946
# 3  Hollywood          646         2     900
# 4    Central          176         1     122
#
#                                          Crm Cd Desc  ... Status
# 0                           VIOLATION OF COURT ORDER  ...     AA  \
# 1  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...  ...     IC
# ...

# %%
import pandas as pd   #DEALING WITH MISSING VALUES

# Re-loading the dataset due to execution state reset
file_path =  "C:\\Users\\Parag\\Desktop\\assesment2\\parag\\Crime_Data_from_2010_to_2019.csv"
crime_data = pd.read_csv(file_path)

# Data Preprocessing

# Checking for missing values
missing_values = crime_data.isnull().sum()

# Checking data types
data_types = crime_data.dtypes

# Basic summary statistics for numerical columns
summary_statistics = crime_data.describe()

missing_values, data_types, summary_statistics
# Out:
# (DR_NO                   0
#  Date Rptd               0
#  DATE OCC                0
#  TIME OCC                0
#  AREA                    0
#  AREA NAME               0
#  Rpt Dist No             0
#  Part 1-2                0
#  Crm Cd                  0
#  Crm Cd Desc             0
#  Mocodes            240264
#  Vict Age                0
#  Vict Sex           213468
#  Vict Descent       213502
#  Premis Cd              47
#  Premis Desc           503
#  Weapon Used Cd    1358248
#  Weapon Desc       1358248
#  Status                  2
#  Status Desc             0
#  Crm Cd 1                8
#  Crm Cd 2          1914232
#  Crm Cd 3          2049462
#  Crm Cd 4          2053284
#  LOCATION                0
#  Cross Street      1711173
#  LAT                     0
#  LON                     0
#  dtype: int64,
#  DR_NO               int64
#  Date Rptd          object
#  DATE OCC           object
#  TIME OCC            int64
#  AREA                int64
# ...

# %%
import pandas as pd #PREPROCESSING

# Re-loading the dataset due to execution state reset
file_path = "C:\\Users\\Parag\\Desktop\\assesment2\\parag\\Crime_Data_from_2010_to_2019.csv"
crime_data = pd.read_csv(file_path)

# Preprocessing Steps

# 1. Handling Missing Values
# Filling missing values in 'Vict Sex' and 'Vict Descent' with 'Unknown'
# Dropping columns with a large number of missing values that are not critical for basic analysis
columns_to_drop = ['Mocodes', 'Weapon Used Cd', 'Weapon Desc', 'Crm Cd 2', 'Crm Cd 3', 'Crm Cd 4', 'Cross Street']
crime_data['Vict Sex'].fillna('Unknown', inplace=True)
crime_data['Vict Descent'].fillna('Unknown', inplace=True)
crime_data.drop(columns=columns_to_drop, inplace=True)

# 2. Convert Data Types
# Converting 'Date Rptd' and 'DATE OCC' to datetime format
crime_data['Date Rptd'] = pd.to_datetime(crime_data['Date Rptd'])
crime_data['DATE OCC'] = pd.to_datetime(crime_data['DATE OCC'])

# 3. Handle Anomalous Values
# Replacing 0 values in LAT and LON with NaN
crime_data['LAT'].replace(0, pd.NA, inplace=True)
crime_data['LON'].replace(0, pd.NA, inplace=True)

# 4. Data Transformation
# Extracting year and month from 'DATE OCC' for easier analysis
crime_data['Year'] = crime_data['DATE OCC'].dt.year
crime_data['Month'] = crime_data['DATE OCC'].dt.month

# Checking the dataset after preprocessing
crime_data.head()
# Out:
# C:\Users\Parag\AppData\Local\Temp\ipykernel_28516\1780546436.py:19: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   crime_data['Date Rptd'] = pd.to_datetime(crime_data['Date Rptd'])
# C:\Users\Parag\AppData\Local\Temp\ipykernel_28516\1780546436.py:20: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   crime_data['DATE OCC'] = pd.to_datetime(crime_data['DATE OCC'])
#        DR_NO  Date Rptd   DATE OCC  TIME OCC  AREA   AREA NAME  Rpt Dist No
# 0    1307355 2010-02-20 2010-02-20      1350     13     Newton         1385  \
# 1   11401303 2010-09-13 2010-09-12        45     14    Pacific         1485
# 2   70309629 2010-08-09 2010-08-09      1515     13     Newton         1324
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Re-loading the dataset due to execution state reset
file_path = "C:\\Users\\Parag\\Desktop\\assesment2\\parag\\Crime_Data_from_2010_to_2019.csv"
crime_data = pd.read_csv(file_path)

# Preprocessing the dataset again quickly for visualization
crime_data['Date Rptd'] = pd.to_datetime(crime_data['Date Rptd'])
crime_data['DATE OCC'] = pd.to_datetime(crime_data['DATE OCC'])
crime_data['Year'] = crime_data['DATE OCC'].dt.year
crime_data['Month'] = crime_data['DATE OCC'].dt.month

# Setting up the visualization style
sns.set(style="whitegrid")

# Exploratory Data Analysis and Visualization

# 1. Yearly Crime Trends
yearly_crime_counts = crime_data['Year'].value_counts().sort_index()

plt.figure(figsize=(12, 6))
yearly_crime_counts.plot(kind='bar', color='skyblue')
plt.title('Yearly Crime Counts (2010-2019)')
plt.xlabel('Year')
plt.ylabel('Number of Crimes')
plt.xticks(rotation=45)
plt.show()

# 2. Crime Type Distributions
top_crime_types = crime_data['Crm Cd Desc'].value_counts().head(10)

plt.figure(figsize=(12, 6))
sns.barplot(x=top_crime_types.values, y=top_crime_types.index, palette='viridis')
plt.title('Top 10 Crime Types')
plt.xlabel('Number of Occurrences')
plt.ylabel('Crime Type')
plt.show()
# Out:
# C:\Users\Parag\AppData\Local\Temp\ipykernel_28516\2804846036.py:10: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   crime_data['Date Rptd'] = pd.to_datetime(crime_data['Date Rptd'])
# C:\Users\Parag\AppData\Local\Temp\ipykernel_28516\2804846036.py:11: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   crime_data['DATE OCC'] = pd.to_datetime(crime_data['DATE OCC'])

# %%
# Monthly Crime Trends Analysis
monthly_crime_counts = crime_data.groupby('Month').size()

# Plotting Monthly Crime Trends
plt.figure(figsize=(10, 6))
sns.barplot(x=monthly_crime_counts.index, y=monthly_crime_counts.values)
plt.title('Monthly Crime Trends')
plt.xlabel('Month')
plt.ylabel('Number of Crimes')
plt.xticks(range(0, 12), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.tight_layout()
plt.show()

# Time of Day Analysis
# Extracting hour from TIME OCC
crime_data['Hour'] = crime_data['TIME OCC'] // 100
hourly_crime_counts = crime_data.groupby('Hour').size()

# Plotting Time of Day Crime Trends
plt.figure(figsize=(10, 6))
sns.barplot(x=hourly_crime_counts.index, y=hourly_crime_counts.values)
plt.title('Time of Day Crime Trends')
plt.xlabel('Hour of Day (24-hour format)')
plt.ylabel('Number of Crimes')
plt.tight_layout()
plt.show()

# Geographical Analysis - Area wise Crime Distribution
area_crime_counts = crime_data['AREA NAME'].value_counts()

# Plotting Area wise Crime Distribution
plt.figure(figsize=(10, 6))
sns.barplot(y=area_crime_counts.index, x=area_crime_counts.values)
plt.title('Area Wise Crime Distribution')
plt.xlabel('Number of Crimes')
plt.ylabel('Area Name')
plt.tight_layout()
plt.show()

# Correlation Analysis - To be done later as it requires more complex statistical methods

# Type of Crime by Year
crime_type_by_year = pd.crosstab(crime_data['Year'], crime_data['Crm Cd Desc'])
top_crimes = crime_data['Crm Cd Desc'].value_counts().head(5).index
crime_type_by_year_top = crime_type_by_year[top_crimes]

# Plotting Type of Crime by Year for Top 5 Crimes
plt.figure(figsize=(10, 6))
sns.lineplot(data=crime_type_by_year_top)
plt.title('Top 5 Types of Crime by Year')
plt.xlabel('Year')
plt.ylabel('Number of Crimes')
plt.legend(title='Crime Type', labels=top_crimes)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# Convert date columns to datetime
crime_data['DATE OCC'] = pd.to_datetime(crime_data['DATE OCC'])

# Extract year for time series analysis
crime_data['Year'] = crime_data['DATE OCC'].dt.year

# Time Series Analysis: Overall Crime Trends over the Years 2010-2019
# Counting the number of crimes per year
yearly_crime_counts = crime_data['Year'].value_counts().sort_index()

# Plotting
plt.figure(figsize=(12, 6))
sns.lineplot(data=yearly_crime_counts, marker='o')
plt.title('Overall Crime Trends from 2010 to 2019')
plt.xlabel('Year')
plt.ylabel('Number of Crimes')
plt.grid(True)
plt.show()
# Out:
# C:\Users\Parag\AppData\Local\Temp\ipykernel_28516\2362712378.py:6: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   crime_data['DATE OCC'] = pd.to_datetime(crime_data['DATE OCC'])
